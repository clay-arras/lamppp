def _to_row_major(mat):
    return torch.tensor(mat).flatten().tolist()
def _from_row_major(flat, like):
    t = torch.tensor(flat).reshape(torch.tensor(like).shape)
    return t.tolist()
def _to_cpp_tensor(mat):
    ten = cpp_custom_bind.cTensor(_to_row_major(mat), list(torch.tensor(mat).shape))
    return ten

# Create torch tensors and add them
torch_tensor1 = torch.tensor(mats[0], dtype=torch.float64)
torch_tensor2 = torch.tensor(mats[1], dtype=torch.float64)
torch_sum = torch_tensor1 + torch_tensor2

# Create cpp tensors and add them
cpp_tensor1 = _to_cpp_tensor(mats[0])
cpp_tensor2 = _to_cpp_tensor(mats[1])
cpp_sum = cpp_custom_bind.add_tensor(cpp_tensor1, cpp_tensor2)

# Convert results back to lists for comparison
torch_result = torch_sum.tolist()
cpp_result = _from_row_major(cpp_sum.data, torch_result)

print("Torch result shape:", torch_sum.shape)
print("First few values:")
print("Torch:", torch_result[0][:3])
print("CPP:", cpp_result[0][:3])
print("\nMax difference:", torch.max(torch.abs(torch.tensor(torch_result) - torch.tensor(cpp_result))).item())
# Out:
# Torch result shape: torch.Size([12, 12])
# First few values:
# Torch: [-10.822877578768978, -10.648017509516022, 1.9272855575997454]
# CPP: [-10.822877883911133, -10.648017883300781, 1.9272856712341309]
#
# Max difference: 9.5367431640625e-07

# %%
mats = [[[-2.2371197030046153, -3.716369107538755, 2.6863395530878176, 2.4971173344007056, -8.880263875866405, 9.006156482110374, 1.1710522238264147, -2.339264623703599, 5.591384025576424, -9.065065356059424, -5.233047643476098, -8.447935877772126], [-0.0960580147058856, 0.13558321334249257, -2.8651300087466947, 8.020791303579696, -2.364986913337887, -9.079460984909705, -6.577965194863733, 4.9496275232436275, 9.792300768536567, 5.233367123570501, -8.749208364843394, -4.982186890725309], [-6.1109108386261095, -2.42356364843316, -5.670426220962725, -0.18677768740326073, -5.868263881274687, 2.827509189717741, -9.758674580912626, -7.972992169983222, -6.150724605827054, 8.154534147955733, -3.155278212756243, -7.502670630091687], [-8.949105001073324, 0.3129544128120223, 5.5836378617248155, -0.5107516745724254, -9.616098422461262, -6.816519112254351, -4.601364828377474, -3.349594618912583, 4.1755087325660885, 8.157994982756613, 5.627879814678172, -5.005651995449105], [5.388044102599146, -5.62446875283642, 0.41932107138848096, -1.7598077908513865, -0.7309733238063032, -3.1932075739254167, -8.364796747490056, -8.118565608907826, 3.5661265193777947, -9.593436824151302, -6.396472852937505, 6.398183794791084], [-4.692351708105102, -3.721787683599384, -0.05272411989398762, 3.4835255887240724, 8.219196836748367, -8.630212681643396, 7.571084766855719, 0.04253782808591211, -7.169991786929549, -7.034498248805747, 7.3073232363850735, -4.745874242715907], [9.108171709281283, -2.703679166380841, 9.22595108300112, -3.647571655543411, -
-5.316384844452376, 9.378080302601639, -5.387509783170598, -7.410347251829474], [9.450740787159656, -5.407233540265837, -0.6112298278533537, 1.1583523019086641, -2.9254005167698143, 5.532910630050274, -5.861802043827495, 3.0413795740366325, -3.2717572065435485, -5.049112987390975, -2.0082097342424943, -5.1190724503997265], [-6.280134092910754, 0.8077981737143354, 4.78783651974968, -6.480677755586301, 1.584736243621105, -3.9392138359846225, -1.2627099814444698, 0.5202549303746586, -5.895843203597131, -6.293601088092302, -4.371831116953753, -9.315023471452836], [5.268293219528005, -9.278892342193695, -7.855052661424542, 5.99849739300401, 8.6123094460882, 6.015703740304211, -2.6891834242315715, 5.06450022139755, 3.8123735350218375, -3.2322878019059287, -1.2396352118765854, -9.173908312221695], [-3.4351000374614067, 4.378399031012206, 7.530477821794356, -2.463100470400123, 1.344602467966137, 0.9103864947954854, -0.2504390846768487, 6.912077602879798, 8.176790750578448, -9.715741629877567, 2.0496191909981416, 1.3227553809523975], [-7.373547829858273, -2.501297769886362, 1.8491863356045215, 7.269221520708427, 8.992634597271898, -7.259352225506122, -2.5086123165149683, 1.3860118498838663, 4.237655509529667, -6.103553051025974, 9.029926836234885, 7.796248377055601]]]

def _to_row_major(mat):
    return torch.tensor(mat).flatten().tolist()
def _from_row_major(flat, like):
    t = torch.tensor(flat).reshape(torch.tensor(like).shape)
    return t.tolist()
def _to_cpp_tensor(mat):
    ten = cpp_custom_bind.cTensor(_to_row_major(mat), list(torch.tensor(mat).shape))
    return cpp_custom_bind.cVariable(ten, False)

torch_tensor1 = torch.tensor(mats[0], dtype=torch.float64)
torch_tensor2 = torch.tensor(mats[1], dtype=torch.float64)
torch_sum = torch_tensor1 + torch_tensor2

cpp_tensor1 = _to_cpp_tensor(mats[0])
cpp_tensor2 = _to_cpp_tensor(mats[1])
cpp_sum = cpp_custom_bind.add(cpp_tensor1, cpp_tensor2)

torch_result = torch_sum.tolist()
cpp_result = _from_row_major(cpp_sum.data.data, torch_result)

print("Torch result shape:", torch_sum.shape)
print("First few values:")
print("Torch:", torch_result[0][:20])
print("CPP:", cpp_result[0][:20])
print("\nMax difference:", torch.max(torch.abs(torch.tensor(torch_result) - torch.tensor(cpp_result))))
# Out:
# Torch result shape: torch.Size([12, 12])
# First few values:
# Torch: [-10.822877578768978, -10.648017509516022, 1.9272855575997454, 5.763454958583692, -3.6533641440110785, 18.390987612411884, 10.883553834739843, 5.788577821639041, 5.908234025198105, -5.0352812164706116, -7.851568252856895, -1.1047689025878906]
# CPP: [-10.822877883911133, -10.648017883300781, 1.9272856712341309, 5.763454914093018, -3.653364658355713, 18.390987396240234, 10.883553504943848, 5.788578033447266, 5.908234119415283, -5.035281181335449, -7.851568222045898, -1.104769229888916]
#
# Max difference: tensor(17.9692)
